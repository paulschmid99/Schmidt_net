# %%
import schmid_t_tools as st
import matplotlib.pyplot as plt

# %%
# 1) Nur Netz
fig, ax = st.plot_schmidt_net()
plt.show()

# 2) Netz + Daten aus CSV
fig, ax = st.plot_from_table("orientations_example.csv")
plt.show()
fig.savefig("schmidt_net_orientations_example.png", dpi=400, bbox_inches="tight")
